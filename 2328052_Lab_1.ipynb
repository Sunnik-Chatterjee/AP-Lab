# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunnik-Chatterjee/AP-Lab/blob/main/2328052_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Assign different types of values to different variables, print them and display all the
# variables which you have created. And display the types of all variables and delete a
# particular variable. Assign two variables with integer values then print and compare both

# %%
a = 3
b = 4.5
c = "Sunnik"
d = 5j
print("a  b    c   d")
print(a,b,c,d)
print(type(a),type(b),type(c),type(d))
del a
a = int(input("Enter a integer value: "))
b = int(input("Enter another integer value: "))
print("a = "+str(a))
print("b = "+str(b))
if(a==b):
  print("a=b "+str(a==b))
elif(a>b):
  print("a>b "+str(a>b))
else:
  print("a<b "+str(a<b))
# Out:
# a  b    c   d
# 3 4.5 Sunnik 5j
# <class 'int'> <class 'float'> <class 'str'> <class 'complex'>
# Enter a integer value: 15
# Enter another integer value: 10
# a = 15
# b = 10
# a>b True

# %% [markdown]
# Q2. Write Python program to input a 3-digits integer number then find and display its
# reverse (using operators only).

# %%
a=int(input("Enter a number: "))
rem=0
b=0
while(a>0):
  rem=a%10
  b=b*10+rem
  a=a//10
print(b)
# Out:
# Enter a number: 145
# 541

# %% [markdown]
# Q3. Write a python program to input two numbers and find the biggest one (using operators
# only).

# %%
a=int(input("Enter a number: "))
b=int(input("Enter 2nd number: "))
if(a>b):
  print(a)
elif(a<b):
  print(b)
else:
  print("a=b")
# Out:
# Enter a number: 156
# Enter 2nd number: 651
# 651

# %% [markdown]
# Q4. Initialize a set of elements within a variable and check whether a particular element is
# available within this set or not. (using operator only)

# %%
lang=["C++","Kotlin","C#","Java","Python"]
print("C++" in lang)
# Out:
# True

# %% [markdown]
# Q5. Write Python program to find out the distance between two coordinates (x1, y1) and (x2,
# y2) using only operators.

# %%
x1 = float(input("Enter x1 co-ordinate: "))
y1 = float(input("Enter y1 co-ordinate: "))
x2 = float(input("Enter x2 co-ordinate: "))
y2 = float(input("Enter y2 co-ordinate: "))
dis=((x2-x1)**2+(y2-y1)**2)**0.5
print("Distance between two points is: ",dis)
# Out:
# Enter x1 co-ordinate: 14
# Enter y1 co-ordinate: 12
# Enter x2 co-ordinate: 10
# Enter y2 co-ordinate: 1.111111
# Distance between two points is:  11.600340669752807

# %% [markdown]
# Q6. Write a python program to replace an existing sub-string of a string with a new string.

# %%
a=input("Enter your name: ")
b=("My name is "+a)
print(b)
c=b.replace(a,"Sunnik")
print(c)
# Out:
# Enter your name: Shubhankar
# My name is Shubhankar
# My name is Sunnik

# %% [markdown]
# Q7. Write a python program to show 1 st 5 characters from the given string.

# %%
a="Hello Wumpus in this cruel world!"
a[1:6]
# Out:
# 'ello '

# %% [markdown]
# Q8. Write a python program to show the characters from the given string as per the range.

# %%
a=input("Enter a random string: ")
b=int(input("From which character you want to start to see: "))
c=int(input("Upto which character you want to see: "))
a[b:c+1]
# Out:
# Enter a random string: Hey I am Sunnik Chatterjee
# From which character you want to start to see: 6
# Upto which character you want to see: 19
# 'am Sunnik Chat'

# %% [markdown]
# Q9. Write a python program to display the given string in reverse order.

# %%
a=input("Enter a string which you want to see in reverse order: ")
a[::-1]
# Out:
# Enter a string which you want to see in reverse order: I am Sunnik
# 'kinnuS ma I'

# %% [markdown]
# Q10. Write a python program to capitalize the 1 st letter of each and every word of a string.

# %%
a=input("What is your name: ")
print(a[0:1].upper()+a[1:])
# Out:
# What is your name: sunnik
# Sunnik

# %% [markdown]
# Q11. Write Python program to input a 3-digits number and check whether it is palindrome
# number or not without using any loop.

# %%
a=int(input("Enter a 3 digit number: "))
a=str(a)
b=a[::-1]
print(a==b)
# Out:
# Enter a 3 digit number: 121
# True
